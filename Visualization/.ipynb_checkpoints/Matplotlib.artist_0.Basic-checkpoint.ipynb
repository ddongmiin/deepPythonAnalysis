# %% [markdown]
# # 0. Setting

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # 1. pyplot api

# %%
#figure 생성
plt.figure(figsize=(10, 5))

# %%
#pyplot api subplot 생성하기
plt.figure()
plt.subplot(2, 1, 1)
plt.subplot(2, 1, 2)

# %%
#figure를 쓰지 않아도 동일한 효과
plt.subplot(2, 1, 1)
plt.subplot(2, 1, 2)

# %%
#sample plot1
plt.plot([1, 2, 3])

# %% [markdown]
# # 2. 객체지향형 api

# %%
fig = plt.figure()
ax = fig.subplots()

# %%
fig = plt.figure()
ax = fig.subplots()
ax.bar([1, 2, 3], [2, 3, 4])
# Out:
# <BarContainer object of 3 artists>
